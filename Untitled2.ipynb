# %% [markdown]
# <a href="https://colab.research.google.com/github/fauziahhadijahassagaf/202055202100-fauziah/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
# Membaca file .xlsx
data_xlsx = pd.read_excel('DatasetCuaca_convert.xlsx')

# Menyimpan sebagai file .csv
data_xlsx.to_csv('DatasetCuaca.csv', index=False)

# %%
# Membaca dataset suhu udara
data = pd.read_csv('DatasetCuaca.csv')

# Menghitung Mean
mean = data['Suhu Udara'].mean()

# Menghitung median
median = data['Suhu Udara'].median()

# Menghitung modus
mode = data['Suhu Udara'].mode()

print('Nilai Mean', mean)
print('Nilai Median', median)
print('Nilai Modus',mode)
# Out:
# Nilai Mean 27.16111111111111
# Nilai Median 27.2
# Nilai Modus 0    26.6
# 1    27.2
# 2    27.4
# 3    27.8
# 4    28.0
# Name: Suhu Udara, dtype: float64

# %%
# Membaca dataset suhu udara
data = pd.read_csv('DatasetCuaca.csv')

# Menghitung Mean
mean = data['Curah Hujan'].mean()

# Menghitung median
median = data['Curah Hujan'].median()

# Menghitung modus
mode = data['Curah Hujan'].mode()

print('Nilai Mean', mean)
print('Nilai Median', median)
print('Nilai Modus',mode)
# Out:
# Nilai Mean 273.2527777777778
# Nilai Median 239.6
# Nilai Modus 0      25.9
# 1      35.6
# 2      38.7
# 3      76.7
# 4      81.7
# 5      97.1
# 6     118.1
# 7     121.0
# 8     134.7
# 9     141.0
# 10    147.0
# 11    165.8
# 12    175.0
# 13    180.0
# 14    193.7
# 15    223.5
# 16    233.0
# 17    236.0
# 18    243.2
# 19    283.1
# 20    287.0
# 21    298.0
# 22    302.0
# 23    330.0
# 24    333.9
# 25    360.0
# 26    362.0
# 27    377.0
# 28    391.5
# 29    394.4
# 30    478.0
# 31    511.0
# 32    516.7
# 33    519.0
# 34    678.2
# 35    747.6
# Name: Curah Hujan, dtype: float64

# %%
data = pd.read_csv('DatasetCuaca.csv')

# %%
print(data.describe())
# Out:
#        Suhu Udara  Tekanan Udara  Kelembapan Udara  Kecepatan Angin  \
# count   36.000000      36.000000         36.000000        36.000000
# mean    27.161111    1009.052778         85.294444         4.350000
# std      0.678350       0.959907          3.106670         0.618061
# min     25.600000    1007.200000         78.000000         3.700000
# 25%     26.675000    1008.475000         83.700000         4.000000
# 50%     27.200000    1009.000000         85.050000         4.150000
# 75%     27.800000    1009.525000         88.000000         4.525000
# max     28.400000    1011.400000         90.000000         6.500000
#
#        Curah Hujan
# count    36.000000
# mean    273.252778
# std     176.640231
# min      25.900000
# 25%     139.425000
# 50%     239.600000
# 75%     365.750000
# max     747.600000

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='Suhu Udara', y='Curah Hujan', data=data)
plt.title('Boxplot Suhu Udara dan Curah Hujan')
plt.xlabel('Suhu Udara')
plt.ylabel('Curah Hujan')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Suhu Udara', y='Curah Hujan', data=data)
plt.title('scatterplot Suhu Udara dan Curah Hujan')
plt.xlabel('Suhu Udara')
plt.ylabel('Curah Hujan')
plt.show()

# %%
# Menghitung standar deviasi
std_suhu_udara = data['Suhu Udara'].std()

# Membuat histogram suhu udara
plt.figure(figsize=(10, 6))
plt.hist(data['Suhu Udara'], bins=10, alpha=0.5, color='blue', edgecolor='black', label='Suhu Udara')

# Menambahkan garis vertikal untuk standar deviasi suhu udara
plt.axvline(x=std_suhu_udara, color='red', linestyle='--', linewidth=2, label='standar deviasi suhu udara')

plt.title('Suhu Udara')
plt.xlabel('Nilai')
plt.ylabel('ferkuensi')
plt.legend()
plt.show()

# %%
# Menghitung stndar deviasi
std_curah_hujan =data['Curah Hujan'].std()

# Membuat histogram Curah Hujan
plt.figure(figsize=(8, 6))
plt.hist(data['Curah Hujan'], bins=10, alpha=0.5, color='green', edgecolor='black', label='Curah Hujan')

# Menambahkan garis vertikal untuk standar deviasi Curah Hujan
plt.axvline(x=std_curah_hujan, color='red', linestyle='--', linewidth=2, label='standar deviasi suhu udara')


plt.title('Histogram Curah Hujan')
plt.xlabel('Nilai')
plt.ylabel('ferkuensi')
plt.legend()
plt.show()

# %%
data = pd.read_csv('DatasetCuaca.csv')
